# %% [markdown]
# <a href="https://colab.research.google.com/github/Blancavelazquez/ProyectoDiabetesEquipo7/blob/main/Diabetes_outcome_a_machine_learning_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predicción de diabetes

# %% [markdown]
# ## Equipo 7:
# - Alonso Contreras Guadalupe
# - Moreno Abad Angeles Lucero
# - Rodríguez Rodríguez Areli
# - Velázquez Gil Blanca Andrea

# %% [markdown]
# ## ¿Qué es un proyecto de Machine Learning?
#
# Machine Learning es una rama de la inteligencia artificial (IA) y las ciencias de la computación que se centra en el uso de datos y algoritmos para imitar la forma en que los humanos aprenden, mejorando gradualmente su precisión (¿Qué Es Machine Learning? | IBM, n.d.).
#
# Un proyecto de machine learning se centra en el desarrollo de sistemas o algoritmos capaces de aprender de manera automatizada y mejorar su rendimiento sin intervención humana directa. Este enfoque se basa en la capacidad de los programas computacionales para acceder a datos y utilizarlos para tomar decisiones o realizar predicciones.
#
# El proceso de aprendizaje en el machine learning implica proporcionar datos, instrucciones o ejemplos al programa para que identifique patrones y adquiera información clave, permitiéndole tomar decisiones basadas en datos reales. Los algoritmos de machine learning pueden clasificarse en varias categorías principales, incluyendo algoritmos supervisados, no supervisados, semi-supervisados y de aprendizaje por refuerzo. Estos algoritmos permiten analizar y procesar grandes volúmenes de datos de manera eficiente, con el objetivo de identificar oportunidades, riesgos y tomar decisiones mediante la predicción de información relevante.

# %% [markdown]
# ## Introducción
# La diabetes es una enfermedad metabólica crónica caracterizada por niveles elevados de glucosa en sangre (o azúcar en sangre), que con el tiempo conduce a daños graves en el corazón, los vasos sanguíneos, los ojos, los riñones y los nervios.
# Aproximadamente 62 millones de personas en las Américas (422 millones de personas en todo el mundo) tienen diabetes, la mayoría vive en países de ingresos bajos y medianos, y 244 084 muertes (1.5 millones en todo el mundo) se atribuyen directamente a la diabetes cada año. Tanto el número de casos como la prevalencia de diabetes han aumentado constantemente durante las últimas décadas. (OMS, 2023)

# %% [markdown]
# ## Objetivo
# Construir un modelo de machin learning que pueda predecir con precisión si un paciente tiene diabetes en función a los niveles de hemoglobina glicosilada (HbA1c) y glucosa en sangre.

# %% [markdown]
# Las caracteritics del dataset son:
# - Género: esta es una característica categórica que puede ser "masculina" o "femenina".
# - Edad: Esta es una característica numérica que representa la edad del paciente en años.
# - Hipertensión: esta es una característica categórica que puede ser "0" (sin hipertensión) o "1" (hipertensión).
# - Heart_disease: Esta es una característica categórica que puede ser "0" (sin enfermedad cardíaca) o "1" (enfermedad cardíaca).
# - Smoke_history: Esta es una característica categórica que puede ser "nunca", "nunca" o "fumador actual".
# - IMC: Esta es una característica numérica que representa el índice de masa corporal del paciente.
# - HbA1c_level: Esta es una característica numérica que representa el nivel de HbA1c del paciente, que es una medida del control del azúcar en sangre durante los últimos 3 meses.
# - Blood_glucose_level: Esta es una característica numérica que representa el nivel de glucosa en sangre del paciente en el momento de la prueba.
# - Diabetes: esta es la variable objetivo que predecirá el modelo. Es una característica categórica que puede ser "0" (sin diabetes) o "1" (diabetes).

# %% [markdown]
# ## Dataset seleccionado:
# https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset

# %%
import pandas as pd
from scipy import stats

# %%
# Permiso de lectura de archivos del drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_original = pd.read_csv('/content/drive/MyDrive/Predicción de diabetes/archive.zip', sep = ',', index_col = 0)

# %%
df_original.head(10)
# Out:
#          age  hypertension  heart_disease smoking_history    bmi  HbA1c_level  \
# gender
# Female  80.0             0              1           never  25.19          6.6
# Female  54.0             0              0         No Info  27.32          6.6
# Male    28.0             0              0           never  27.32          5.7
# Female  36.0             0              0         current  23.45          5.0
# Male    76.0             1              1         current  20.14          4.8
# Female  20.0             0              0           never  27.32          6.6
# Female  44.0             0              0           never  19.31          6.5
# Female  79.0             0              0         No Info  23.86          5.7
# Male    42.0             0              0           never  33.64          4.8
# Female  32.0             0              0           never  27.32          5.0
#
#         blood_glucose_level  diabetes
# gender
# Female                  140         0
# Female                   80         0
# Male                    158         0
# Female                  155         0
# Male                    155         0
# Female                   85         0
# Female                  200         1
# Female                   85         0
# Male                    145         0
# Female                  100         0

# %%
df_original
# Out:
#          age  hypertension  heart_disease smoking_history    bmi  HbA1c_level  \
# gender
# Female  80.0             0              1           never  25.19          6.6
# Female  54.0             0              0         No Info  27.32          6.6
# Male    28.0             0              0           never  27.32          5.7
# Female  36.0             0              0         current  23.45          5.0
# Male    76.0             1              1         current  20.14          4.8
# ...      ...           ...            ...             ...    ...          ...
# Female  80.0             0              0         No Info  27.32          6.2
# Female   2.0             0              0         No Info  17.37          6.5
# Male    66.0             0              0          former  27.83          5.7
# Female  24.0             0              0           never  35.42          4.0
# Female  57.0             0              0         current  22.43          6.6
#
#         blood_glucose_level  diabetes
# gender
# Female                  140         0
# Female                   80         0
# Male                    158         0
# Female                  155         0
# Male                    155         0
# ...                     ...       ...
# Female                   90         0
# Female                  100         0
# Male                    155         0
# Female                  100         0
# Female                   90         0
#
# [100000 rows x 8 columns]

# %%
df_original.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi',
#        'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
#Columnas clave que definen nuestro estudio:
columnas_clave = ['age', 'hypertension', 'heart_disease', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']

# %%
#Fraccion en la que se desea dividr el dataframe:
fraccion = 0.1

# Reducir el número de filas de forma proporcional:
df_reducido = df_original.sample(frac=fraccion, random_state=1) # muestra aleatoria del 10% de los datos

#Redefinimos columnas:
df_reducido = df_reducido[columnas_clave]
df_reducido
# Out:
#          age  hypertension  heart_disease    bmi  HbA1c_level  \
# gender
# Female  73.0             0              0  26.62          5.0
# Female  35.0             0              0  27.32          4.5
# Male    38.0             0              0  27.32          6.2
# Female  75.0             0              0  31.11          6.2
# Female  51.0             0              0  39.57          6.2
# ...      ...           ...            ...    ...          ...
# Female  36.0             0              1  31.42          3.5
# Female  35.0             0              0  22.67          4.5
# Male    58.0             0              1  27.32          5.7
# Male    27.0             0              0  24.68          5.0
# Female  60.0             0              0  27.32          4.5
#
#         blood_glucose_level  diabetes
# gender
# Female                  155         0
# Female                  130         0
# Male                    130         0
# Female                  159         0
# Female                  240         1
# ...                     ...       ...
# Female                  160         0
# Female                   85         0
# Male                    100         0
# Male                    160         0
# Female                  145         0
#
# [10000 rows x 7 columns]

# %%
#Reindexando:
df_reducido = df_reducido.reset_index(drop=True)
df_reducido
# Out:
#        age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0     73.0             0              0  26.62          5.0
# 1     35.0             0              0  27.32          4.5
# 2     38.0             0              0  27.32          6.2
# 3     75.0             0              0  31.11          6.2
# 4     51.0             0              0  39.57          6.2
# ...    ...           ...            ...    ...          ...
# 9995  36.0             0              1  31.42          3.5
# 9996  35.0             0              0  22.67          4.5
# 9997  58.0             0              1  27.32          5.7
# 9998  27.0             0              0  24.68          5.0
# 9999  60.0             0              0  27.32          4.5
#
#       blood_glucose_level  diabetes
# 0                     155         0
# 1                     130         0
# 2                     130         0
# 3                     159         0
# 4                     240         1
# ...                   ...       ...
# 9995                  160         0
# 9996                   85         0
# 9997                  100         0
# 9998                  160         0
# 9999                  145         0
#
# [10000 rows x 7 columns]

# %%
#Copia del dataframe con el que trabajaremos:
df = df_reducido.copy()

#Dimesiones del dataframe
df.shape
# Out:
# (10000, 7)

# %%
#Tipos de datos en cada columna:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  10000 non-null  float64
#  1   hypertension         10000 non-null  int64
#  2   heart_disease        10000 non-null  int64
#  3   bmi                  10000 non-null  float64
#  4   HbA1c_level          10000 non-null  float64
#  5   blood_glucose_level  10000 non-null  int64
#  6   diabetes             10000 non-null  int64
# dtypes: float64(3), int64(4)
# memory usage: 547.0 KB

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
# Analisis de correlacion de los datos para elegir un par de datos para un futuro modelo ML
sns.heatmap(df.corr(), vmin= -1, vmax= 1, annot= True)
# Out:
# <Axes: >

# %% [markdown]
# Los datos con mayor correlación son HbA1c y glucosa en sangre.

# %%
df['blood_glucose_level'].unique()
# Out:
# array([155, 130, 159, 240, 140, 126, 145,  85, 158,  80, 200, 160, 100,
#         90, 300, 280, 260, 220])

# %%
x, y = make_blobs(n_samples=1000, centers=2, n_features=3)
sns.scatterplot(data= df, x= 'blood_glucose_level', y= 'HbA1c_level', hue= 'diabetes')
plt.show()

# %%
def particionar(entradas, salidas, porcentaje_entrenamiento, porcentaje_validacion, porcentaje_prueba):
    temp_size = porcentaje_validacion + porcentaje_prueba
    x_train, x_temp, y_train, y_temp = train_test_split(entradas, salidas, test_size =temp_size)
    if(porcentaje_validacion > 0):
        test_size = porcentaje_prueba/temp_size
        x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size = test_size)
    else:
        return [x_train, None, x_temp, y_train, None, y_temp]
    return [x_train, x_val, x_test, y_train, y_val, y_test]

# %%
#Usando el 60% para entrenamiento, 10% para validacion y de 30% prueba
[x_train, x_val, x_test, y_train, y_val, y_test] = particionar(df[['blood_glucose_level', 'HbA1c_level']], df['diabetes'],0.60,0.10,0.30)

print('Total del filas del dataset: ', df.shape[0])
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# Total del filas del dataset:  10000
# (6000, 2)
# (1000, 2)
# (3000, 2)

# %%
#Usando el 70% para entrenamiento, 10% para la validacion y 20% de prueba
[x_train, x_val, x_test, y_train, y_val, y_test] = particionar(df[['blood_glucose_level', 'HbA1c_level']], df['diabetes'], 0.70, 0.10, 0.20)

print('Total del filas del dataset: ', df.shape[0])
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# Total del filas del dataset:  10000
# (6999, 2)
# (1000, 2)
# (2001, 2)

# %% [markdown]
# Utilizaremos validacion cruzada para evaluar el modelo

# %%
import numpy as np
from sklearn.model_selection import KFold

# %%
data = df.copy()
k = 1000

kfold = KFold(n_splits=k, shuffle=True, random_state=42)

ciclo = 1
for indices_train, indices_test in kfold.split(data):
    print("Ciclo: " + str(ciclo))
    print("\t datos para entrenamiento:" + str(data.iloc[indices_train]))
    print("\t datos para prueba:" + str(data.iloc[indices_test]))
    ciclo += 1

x, y = make_blobs(n_samples=1000, centers=2, n_features=2)

K = y.shape[0]
random_seed = 48
aleatorio = True

kfold = KFold(n_splits=K, shuffle=aleatorio, random_state=random_seed)
ciclo = 1
for indices_train, indices_test in kfold.split(x):
    print("Ciclo: "+str(ciclo))

    print("Usare "+str(x[indices_train].shape)+" datos para entrenar (entrada)")
    print("Usare "+str(y[indices_train].shape)+" datos para entrenar (salida)")

    print("Usare "+str(x[indices_test].shape)+" datos para probar (entrada)")
    print("Usare "+str(y[indices_test].shape)+" datos para probar (salida)")
    ciclo+=1
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Ciclo: 1
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 2
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 3
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 4
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 5
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 6
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 7
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 8
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 9
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 10
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 11
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 12
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 13
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 14
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 15
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 16
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 17
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 18
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 19
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 20
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 21
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 22
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 23
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 24
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 25
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 26
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 27
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 28
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 29
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 30
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 31
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 32
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 33
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 34
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 35
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 36
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 37
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 38
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 39
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 40
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 41
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 42
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 43
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 44
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 45
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 46
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 47
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 48
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 49
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 50
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 51
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 52
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 53
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 54
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 55
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 56
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 57
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 58
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 59
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 60
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 61
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 62
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 63
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 64
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 65
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 66
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 67
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 68
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 69
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 70
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 71
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 72
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 73
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 74
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 75
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 76
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 77
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 78
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 79
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 80
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 81
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 82
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 83
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 84
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 85
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 86
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 87
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 88
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 89
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 90
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 91
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 92
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 93
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 94
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 95
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 96
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 97
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 98
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 99
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 100
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 101
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 102
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 103
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 104
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 105
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 106
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 107
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 108
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 109
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 110
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 111
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 112
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 113
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 114
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 115
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 116
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 117
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 118
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 119
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 120
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 121
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 122
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 123
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 124
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 125
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 126
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 127
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 128
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 129
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 130
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 131
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 132
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 133
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 134
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 135
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 136
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 137
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 138
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 139
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 140
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 141
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 142
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 143
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 144
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 145
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 146
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 147
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 148
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 149
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 150
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 151
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 152
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 153
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 154
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 155
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 156
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 157
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 158
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 159
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 160
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 161
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 162
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 163
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 164
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 165
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 166
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 167
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 168
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 169
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 170
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 171
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 172
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 173
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 174
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 175
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 176
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 177
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 178
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 179
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 180
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 181
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 182
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 183
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 184
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 185
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 186
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 187
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 188
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 189
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 190
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 191
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 192
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 193
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 194
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 195
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 196
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 197
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 198
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 199
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 200
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 201
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 202
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 203
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 204
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 205
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 206
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 207
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 208
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 209
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 210
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 211
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 212
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 213
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 214
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 215
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 216
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 217
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 218
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 219
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 220
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 221
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 222
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 223
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 224
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 225
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 226
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 227
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 228
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 229
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 230
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 231
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 232
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 233
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 234
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 235
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 236
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 237
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 238
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 239
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 240
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 241
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 242
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 243
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 244
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 245
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 246
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 247
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 248
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 249
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 250
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 251
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 252
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 253
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 254
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 255
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 256
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 257
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 258
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 259
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 260
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 261
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 262
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 263
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 264
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 265
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 266
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 267
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 268
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 269
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 270
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 271
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 272
# Usare (999, 2) datos para entrenar (entrada)
# ...
# Usare (1,) datos para probar (salida)
# Ciclo: 911
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 912
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 913
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 914
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 915
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 916
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 917
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 918
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 919
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 920
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 921
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 922
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 923
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 924
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 925
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 926
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 927
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 928
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 929
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 930
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 931
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 932
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 933
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 934
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 935
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 936
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 937
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 938
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 939
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 940
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 941
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 942
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 943
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 944
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 945
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 946
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 947
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 948
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 949
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 950
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 951
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 952
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 953
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 954
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 955
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 956
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 957
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 958
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 959
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 960
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 961
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 962
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 963
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 964
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 965
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 966
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 967
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 968
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 969
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 970
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 971
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 972
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 973
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 974
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 975
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 976
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 977
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 978
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 979
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 980
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 981
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 982
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 983
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 984
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 985
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 986
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 987
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 988
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 989
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 990
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 991
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 992
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 993
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 994
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 995
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 996
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 997
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 998
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 999
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)
# Ciclo: 1000
# Usare (999, 2) datos para entrenar (entrada)
# Usare (999,) datos para entrenar (salida)
# Usare (1, 2) datos para probar (entrada)
# Usare (1,) datos para probar (salida)

# %% [markdown]
# # K-means Algoritmo (no supervisado)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
df.head()
# Out:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level  \
# 0  73.0             0              0  26.62          5.0                  155
# 1  35.0             0              0  27.32          4.5                  130
# 2  38.0             0              0  27.32          6.2                  130
# 3  75.0             0              0  31.11          6.2                  159
# 4  51.0             0              0  39.57          6.2                  240
#
#    diabetes
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1

# %%
df.plot.scatter(x=4, y=5, c='DarkGreen')
plt.xlabel(Hab1c_level)
plt.ylabel(Blood-glucose-level)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-01c3839c66ab> in <cell line: 2>()
#       1 df.plot.scatter(x=4, y=5, c='DarkGreen')
# ----> 2 plt.xlabel(Hab1c_level)
#       3 plt.ylabel(Blood-glucose-level)
#       4 plt.show()
#
# NameError: name 'Hab1c_level' is not defined

# %%
min_max_scaler = MinMaxScaler()
df = min_max_scaler.fit_transform(df)
df = pd.DataFrame(df) # Convertimos a Dataframe

# %%
#Encontrando numero de clusters con el método Elbow

import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []  # Initialize wcss as an empty list

for i in np.arange(0, 1):
  kmeans = KMeans (1)
  kmeans.fit(x)
  wcss_iter = kmeans.inertia_
  wcss.append(wcss_iter)

number_clusters = range(0, 1)
plt.plot(number_clusters,wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0, 0.5, 'WCSS')

# %%
# Suponemos que k=3
df.head(3)
# Out:
#           0    1    2         3         4         5    6
# 0  0.912412  0.0  0.0  0.269906  0.272727  0.340909  0.0
# 1  0.436937  0.0  0.0  0.281280  0.181818  0.227273  0.0
# 2  0.474474  0.0  0.0  0.281280  0.490909  0.227273  0.0

# %%
# Aplicamos k-means a nuestro dataset
km = KMeans(n_clusters=3, init='random',
            max_iter=200, random_state=0)
y_km = km.fit_predict(df)
y_km[0:9]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 1, 1, 0, 2, 1, 0, 1, 1], dtype=int32)

# %%
plt.figure(figsize=(8,8))
plt.scatter(df[y_km == 0][0], df[y_km == 0][1],
            s=50, c='green', marker='o',
            edgecolor='black', label='cluster 1')
plt.scatter(df[y_km == 1][0], df[y_km == 1][1],
            s=50, c='orange', marker='s',
            edgecolor='black', label='cluster 2')
plt.scatter(df[y_km == 2][0], df[y_km == 2][1],
            s=50, c='lightblue', marker='v',
            edgecolor='black', label='cluster 3')
plt.scatter(km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 1], s=200,
            marker='*', c='red',
            edgecolor='black', label='centroides')
plt.legend(loc="best")
plt.grid()
plt.show()

# %% [markdown]
# ###Como podemos ver, al aplicar el algortimo k-means para Habc1_level y blood_glucose_level tenemos resultado inusual. Ahora intentaremos con las variables bmi y Habc1_level

# %%
df.plot.scatter(x=3, y=4, c='DarkGreen')
plt.show()

# %%
min_max_scaler = MinMaxScaler()
df = min_max_scaler.fit_transform(df)
df = pd.DataFrame(df) # Convertimos a Dataframe

# %%
# Mostramos los datos escalados
df.head(3)
# Out:
#           0    1    2         3         4         5    6
# 0  0.912412  0.0  0.0  0.269906  0.272727  0.340909  0.0
# 1  0.436937  0.0  0.0  0.281280  0.181818  0.227273  0.0
# 2  0.474474  0.0  0.0  0.281280  0.490909  0.227273  0.0

# %%
#Encontrando numero de clusters WCSS and elbow method wcss=[]

import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []  # Initialize wcss as an empty list

for i in np.arange(0, 2):
  kmeans = KMeans (1)
  kmeans.fit(x)
  wcss_iter = kmeans.inertia_
  wcss.append(wcss_iter)

number_clusters = range(0, 2)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0, 0.5, 'WCSS')

# %%
# Aplicamos k-means a nuestro dataset
km = KMeans(n_clusters=3, init='random',
            max_iter=200, random_state=0)
y_km = km.fit_predict(df)
y_km[0:9]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 1, 1, 0, 2, 1, 0, 1, 1], dtype=int32)

# %%
plt.figure(figsize=(8,8))
plt.scatter(df[y_km == 0][0], df[y_km == 0][1],
            s=50, c='green', marker='o',
            edgecolor='black', label='cluster 1')
plt.scatter(df[y_km == 1][0], df[y_km == 1][1],
            s=50, c='orange', marker='s',
            edgecolor='black', label='cluster 2')
plt.scatter(df[y_km == 2][0], df[y_km == 2][1],
            s=50, c='lightblue', marker='v',
            edgecolor='black', label='cluster 3')
plt.scatter(km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 1], s=200,
            marker='*', c='red',
            edgecolor='black', label='centroides')
plt.legend(loc="best")
plt.grid()
plt.show()

# %% [markdown]
# ### Nuevamente, tenemos un resultado inusal con k-means. Para este conjunto de datos no es la mejor opción el algoritmo no supervisado, sin embargo puede ocurrir el caso contrario

# %% [markdown]
# # Árboles de decisión

# %%
import numpy as np
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
#Caracteristicas:

#Nivel HA1bc | Nivel de glucosa como mínimo para tener diabetes
glucose_level_diabetes = 200
HbA1c_level_diabetes = 6.5

#Variable objetivo 'diabetes':
df['diabetes'] = ((df['blood_glucose_level'] >= glucose_level_diabetes) | (df['HbA1c_level'] >= HbA1c_level_diabetes)).astype(int)

#Características y salida
X = df.drop('diabetes', axis=1)
Y = df['diabetes']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, random_state=42)

# Crear el modelo de árbol de decisiones
arbol = tree.DecisionTreeClassifier()
arbol = arbol.fit(X_train, Y_train)

#Arbol de forma esquemática
plt.figure(figsize = (4,4), dpi = 300)
tree.plot_tree(arbol,filled = True);
plt.show()

# %% [markdown]
# ### Interpretación:
# El árbol de decisión anterior representa el conjunto de reglas que se utilizan para predecir la presencia o ausencia de diabetes en función de los niveles de HA1bc (hemoglobina A1bc) y glucosa en la sangre de los pacientes registrados.
#
# En la primer división se evalua si los valores registrados están por debajo o igual al umbral determinado de HA1bc que define a una persona diabética.
# Si el nivel de la característica en cuestión es menor o igual al umbral definido en la primera división, el árbol se ramifica a la izquierda, lo que indica una mayor probabilidad de que el paciente no tenga diabetes. Por otro lado, si el nivel de la característica supera el umbral, el árbol se ramifica a la derecha, lo que indica una mayor probabilidad de que el paciente tenga diabetes.
#
# En la segunda división se evalua si los valores registrados están por abajo o igual al umbral determinado para niveles de glucosa, donde observamos que después de esta, 5713 muestras pertenecen a la clase 0 (no diabetes) y 600 muestras pertenecen a la clase 1 (diabetes). Siendo estas las predicciones de diabetes para los datos obtenidos.

# %% [markdown]
# # CREACIÓN DE RED NEURONAL

# %%
#Declaramos librerías y dividimos datos para entrenamiento
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

x = df[['HbA1c_level', 'blood_glucose_level']].values
y = df['diabetes'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
#Clasificación MLP
redNeuronal = MLPClassifier(hidden_layer_sizes= (6,4), max_iter= 10000, activation= 'logistic')
redNeuronal.fit(x_train, y_train)
y_pred = redNeuronal.predict(x_test)
print ('El entrenamiento se ha concluido con exito')
# Out:
# El entrenamiento se ha concluido con exito

# %%
# Precisión con matriz de confusión
from sklearn.metrics import confusion_matrix
resultado = confusion_matrix(y_test, y_pred)
print (resultado)

diagonal = np.trace(resultado)
accuracy = (diagonal/y_test.shape[0])*100
print ('Precisión: ' + str(accuracy) + '%')
# Out:
# [[1414    0]
#  [  36  550]]
# Precisión: 98.2%

# %%
# Contar el número de personas con (1) y sin (0) diabetes en el dataset
num_diabetes = np.sum(df['diabetes'] == 1)
num_no_diabetes = np.sum(df['diabetes'] == 0)

print("Número de personas con diabetes:", num_diabetes)
print("Número de personas sin diabetes:", num_no_diabetes)
# Out:
# Número de personas con diabetes: 2885
# Número de personas sin diabetes: 7115

# %%
# Usaremos la predicción para contabilizar
y_pred = redNeuronal.predict(x_test)

# Conteo de personas con (1) y sin (0) diabetes
num_diabetes_pred = np.sum(y_pred == 1)
num_no_diabetes_pred = np.sum(y_pred == 0)

print("Predicción de personas con diabetes:", num_diabetes_pred*5) #multiplicamos x5 ya que nuestra muestra es del 20% de el tamaño total del dataset
print("Predicción de personas sin diabetes:", num_no_diabetes_pred*5)
# Out:
# Predicción de personas con diabetes: 2715
# Predicción de personas sin diabetes: 7285

# %% [markdown]
# Podemos determinar que nuestro modelo tiene una precisión del 98.2% al predecir si una persona puede tener o no diabetes basandonos en los niveles de glucosa en sangre y la hemoglobina glicosilada (HbA1c), se hizo la prueba con multiples valores, se llegó al 100% de precisión en algunos casos pero se decidió seguir experimentando para intentar evitar en medida de lo posible el overfitting.

# %% [markdown]
# #Selección de Modelos
# ### Anteriormente ya trabajamos con el Árbol de Desición y con una Red Neuronal, escogimos la Red Neuronal por su precisión del 98%
